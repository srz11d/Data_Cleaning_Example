# %% [markdown]
# # Data cleaning Example

# %% [markdown]
# ## For this specific example, we have to download data
# ### Importing data to Excel is different in Mac:
#
# 1. Get the link, copy and paste it into a Word document
# https://www.espncricinfo.com/records/highest-career-batting-average-282910
#
# 2. Save the document as plain text (txt) but add the extension .iqy
# 3. Go to Excel, click on Data (on the toolbar) and select Get External Data
# 4. Select the Document. If the document is not available for selection, press 'right' click to display a new window and select Rename
# 5. The option Rename will make the link available
# 6. Click Get Data and done!
# 7. Save the new table as .csv

# %% [markdown]
# Drag the csv file to Jupyter, click on Upload
# This table contains null values, duplicates, + and * signs that we will have to clean

# %%
# Import pandas
import pandas as pd

# %%
#Import the csv
df = pd.read_csv('ESPN.csv')

# %%
# Make sure the file is okay
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 4     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 62   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 63  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 64  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 65    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 66   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7  626+   6
# 1   91.76    4   7   1   141  23
# 2   55.68    5   4   2   186   5
# 3   55.68    5   4   2   186   5
# 4   54.48    7  11   1  246+  11
# ..    ...  ...  ..  ..   ...  ..
# 62  49.16   15  33   4  525+  23
# 63  59.67   27  38  11  1165  24
# 64  44.77    7   6   1  119+   0
# 65  60.02    6  13   4  241+  5+
# 66  25.59    1  10   2   53+   0
#
# [67 rows x 15 columns]

# %%
# Rename columns to make them clearer
df = df.rename(columns = {'NO':'Not_outs','HS':'Highest_inns_score','BF':'Balls_face','SR':'Batting_strike'})

# %%
#Check the new names
df
# Out:
#                Player       Span  Mat  Inns  Not_outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948   52    80        10  6996
# 1      HC Brook (ENG)  2022-2023   12    20         1  1181
# 2      AC Voges (AUS)  2015-2016   20    31         7  1485
# 3      AC Voges (AUS)  2015-2016   20    31         7  1485
# 4     RG Pollock (SA)  1963-1970   23    41         4  2256
# ..                ...        ...  ...   ...       ...   ...
# 62   KD Walters (AUS)  1965-1981   74   125        14  5357
# 63  GC Smith (ICC/SA)  2002-2014  117   205        13  9265
# 64  WH Ponsford (AUS)  1924-1934   29    48         4  2122
# 65    SJ McCabe (AUS)  1930-1938   39    62         5  2748
# 66   DR Jardine (ENG)  1928-1934   22    33         6  1296
#
#    Highest_inns_score    Ave Balls_face Batting_strike  100  50   0    4s  6s
# 0                 334  99.94      9800+           58.6   29  13   7  626+   6
# 1                 186  62.15       1287          91.76    4   7   1   141  23
# 2                269*  61.87       2667          55.68    5   4   2   186   5
# 3                269*  61.87       2667          55.68    5   4   2   186   5
# 4                 274  60.97      1707+          54.48    7  11   1  246+  11
# ..                ...    ...        ...            ...  ...  ..  ..   ...  ..
# 62                250  48.26      8662+          49.16   15  33   4  525+  23
# 63                277  48.25      15525          59.67   27  38  11  1165  24
# 64                266  48.22      3118+          44.77    7   6   1  119+   0
# 65                232  48.21      3217+          60.02    6  13   4  241+  5+
# 66                127  48.00      2110+          25.59    1  10   2   53+   0
#
# [67 rows x 15 columns]

# %%
## Check for null values
df.isnull().any()
# Out:
# Player                False
# Span                  False
# Mat                   False
# Inns                  False
# Not_outs              False
# Runs                  False
# Highest_inns_score    False
# Ave                   False
# Balls_face             True
# Batting_strike         True
# 100                   False
# 50                    False
# 0                     False
# 4s                    False
# 6s                    False
# dtype: bool

# %%
#We need to find where those null values are located
#With this code we are looking for the null values on each category
df[df['Balls_face'].isna()==1]
# Out:
#              Player       Span  Mat  Inns  Not_outs  Runs Highest_inns_score  \
# 17  CL Walcott (WI)  1948-1960   44    74         7  3798                220
#
#       Ave Balls_face Batting_strike  100  50  0    4s  6s
# 17  56.68        NaN            NaN   15  14  1  107+  11

# %%
#We can now fix it and we add 0 instead of null
df['Balls_face'] = df['Balls_face'].fillna(0)

# %%
#We do the same for Batting strike
df[df['Batting_strike'].isna()==1]
# Out:
#              Player       Span  Mat  Inns  Not_outs  Runs Highest_inns_score  \
# 9    ED Weekes (WI)  1948-1958   48    81         5  4455                207
# 17  CL Walcott (WI)  1948-1960   44    74         7  3798                220
#
#       Ave Balls_face Batting_strike  100  50  0    4s  6s
# 9   58.61                       NaN   15  19  6  258+   2
# 17  56.68          0            NaN   15  14  1  107+  11

# %%
#We can now fix it and we add 0 instead of null
df['Batting_strike'] = df['Batting_strike'].fillna(0)

# %%
#We now check the values are corrected
df[df['Player']=='ED Weekes (WI)']
# Out:
#            Player       Span  Mat  Inns  Not_outs  Runs Highest_inns_score  \
# 9  ED Weekes (WI)  1948-1958   48    81         5  4455                207
#
#      Ave Balls_face Batting_strike  100  50  0    4s 6s
# 9  58.61                         0   15  19  6  258+  2

# %%
df[df['Player']=='CL Walcott (WI)']
# Out:
#              Player       Span  Mat  Inns  Not_outs  Runs Highest_inns_score  \
# 17  CL Walcott (WI)  1948-1960   44    74         7  3798                220
#
#       Ave Balls_face Batting_strike  100  50  0    4s  6s
# 17  56.68          0              0   15  14  1  107+  11

# %%
## Drop duplicates
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# Length: 67, dtype: bool

# %%
#Let's find who the duplicates are
df[df['Player'].duplicated()==1]
# Out:
#              Player       Span  Mat  Inns  Not_outs  Runs Highest_inns_score  \
# 3    AC Voges (AUS)  2015-2016   20    31         7  1485               269*
# 16   JB Hobbs (ENG)  1908-1930   61   102         7  5410                211
# 24  VG Kambli (IND)  1993-1995   17    21         1  1084                227
#
#       Ave Balls_face Batting_strike  100  50  0    4s 6s
# 3   61.87       2667          55.68    5   4  2   186  5
# 16  56.94      5363+          46.22   15  28  4  276+  8
# 24  54.20       1823          59.46    4   3  3   124  6

# %%
#We can see where the data is duplicated
df[df['Player'].isin(['AC Voges (AUS)', 'JB Hobbs (ENG)', 'VG Kambli (IND)'])]
# Out:
#              Player       Span  Mat  Inns  Not_outs  Runs Highest_inns_score  \
# 2    AC Voges (AUS)  2015-2016   20    31         7  1485               269*
# 3    AC Voges (AUS)  2015-2016   20    31         7  1485               269*
# 15   JB Hobbs (ENG)  1908-1930   61   102         7  5410                211
# 16   JB Hobbs (ENG)  1908-1930   61   102         7  5410                211
# 23  VG Kambli (IND)  1993-1995   17    21         1  1084                227
# 24  VG Kambli (IND)  1993-1995   17    21         1  1084                227
#
#       Ave Balls_face Batting_strike  100  50  0    4s 6s
# 2   61.87       2667          55.68    5   4  2   186  5
# 3   61.87       2667          55.68    5   4  2   186  5
# 15  56.94      5363+          46.22   15  28  4  276+  8
# 16  56.94      5363+          46.22   15  28  4  276+  8
# 23  54.20       1823          59.46    4   3  3   124  6
# 24  54.20       1823          59.46    4   3  3   124  6

# %%
#Now that we know where they are, we can drop them
df.drop_duplicates()
# Out:
#                Player       Span  Mat  Inns  Not_outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948   52    80        10  6996
# 1      HC Brook (ENG)  2022-2023   12    20         1  1181
# 2      AC Voges (AUS)  2015-2016   20    31         7  1485
# 4     RG Pollock (SA)  1963-1970   23    41         4  2256
# 5     GA Headley (WI)  1930-1954   22    40         4  2190
# ..                ...        ...  ...   ...       ...   ...
# 62   KD Walters (AUS)  1965-1981   74   125        14  5357
# 63  GC Smith (ICC/SA)  2002-2014  117   205        13  9265
# 64  WH Ponsford (AUS)  1924-1934   29    48         4  2122
# 65    SJ McCabe (AUS)  1930-1938   39    62         5  2748
# 66   DR Jardine (ENG)  1928-1934   22    33         6  1296
#
#    Highest_inns_score    Ave Balls_face Batting_strike  100  50   0    4s  6s
# 0                 334  99.94      9800+           58.6   29  13   7  626+   6
# 1                 186  62.15       1287          91.76    4   7   1   141  23
# 2                269*  61.87       2667          55.68    5   4   2   186   5
# 4                 274  60.97      1707+          54.48    7  11   1  246+  11
# 5                270*  60.83       416+             56   10   5   2  104+   1
# ..                ...    ...        ...            ...  ...  ..  ..   ...  ..
# 62                250  48.26      8662+          49.16   15  33   4  525+  23
# 63                277  48.25      15525          59.67   27  38  11  1165  24
# 64                266  48.22      3118+          44.77    7   6   1  119+   0
# 65                232  48.21      3217+          60.02    6  13   4  241+  5+
# 66                127  48.00      2110+          25.59    1  10   2   53+   0
#
# [64 rows x 15 columns]

# %%
#Let's name this new table df
df = df.drop_duplicates()

# %%
#We run the previous line to make sure the duplicates are gone
df[df['Player'].isin(['AC Voges (AUS)', 'JB Hobbs (ENG)', 'VG Kambli (IND)'])]
# Out:
#              Player       Span  Mat  Inns  Not_outs  Runs Highest_inns_score  \
# 2    AC Voges (AUS)  2015-2016   20    31         7  1485               269*
# 15   JB Hobbs (ENG)  1908-1930   61   102         7  5410                211
# 23  VG Kambli (IND)  1993-1995   17    21         1  1084                227
#
#       Ave Balls_face Batting_strike  100  50  0    4s 6s
# 2   61.87       2667          55.68    5   4  2   186  5
# 15  56.94      5363+          46.22   15  28  4  276+  8
# 23  54.20       1823          59.46    4   3  3   124  6

# %%
## Manipulate data
#We can now change, rename and move columns
#First, split up column Span into Start and End
df['Span'].str.split(pat ='-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 4     [1963, 1970]
# 5     [1930, 1954]
#           ...
# 62    [1965, 1981]
# 63    [2002, 2014]
# 64    [1924, 1934]
# 65    [1930, 1938]
# 66    [1928, 1934]
# Name: Span, Length: 64, dtype: object

# %%
#Let's create a new column
df['Rookie_year'] = df['Span'].str.split(pat ='-').str[0]
# Out:
# <ipython-input-59-ce31a1ef08a7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rookie_year'] = df['Span'].str.split(pat ='-').str[0]

# %%
df['Span'].str.split(pat ='-').str[0]
# Out:
# 0     1928
# 1     2022
# 2     2015
# 4     1963
# 5     1930
#       ...
# 62    1965
# 63    2002
# 64    1924
# 65    1930
# 66    1928
# Name: Span, Length: 64, dtype: object

# %%
#And now for the other new column
df['Final_year'] = df['Span'].str.split(pat ='-').str[1]
# Out:
# <ipython-input-61-95d5066b0e19>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Final_year'] = df['Span'].str.split(pat ='-').str[1]

# %%
df
# Out:
#                Player       Span  Mat  Inns  Not_outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948   52    80        10  6996
# 1      HC Brook (ENG)  2022-2023   12    20         1  1181
# 2      AC Voges (AUS)  2015-2016   20    31         7  1485
# 4     RG Pollock (SA)  1963-1970   23    41         4  2256
# 5     GA Headley (WI)  1930-1954   22    40         4  2190
# ..                ...        ...  ...   ...       ...   ...
# 62   KD Walters (AUS)  1965-1981   74   125        14  5357
# 63  GC Smith (ICC/SA)  2002-2014  117   205        13  9265
# 64  WH Ponsford (AUS)  1924-1934   29    48         4  2122
# 65    SJ McCabe (AUS)  1930-1938   39    62         5  2748
# 66   DR Jardine (ENG)  1928-1934   22    33         6  1296
#
#    Highest_inns_score    Ave Balls_face Batting_strike  100  50   0    4s  6s  \
# 0                 334  99.94      9800+           58.6   29  13   7  626+   6
# 1                 186  62.15       1287          91.76    4   7   1   141  23
# 2                269*  61.87       2667          55.68    5   4   2   186   5
# 4                 274  60.97      1707+          54.48    7  11   1  246+  11
# 5                270*  60.83       416+             56   10   5   2  104+   1
# ..                ...    ...        ...            ...  ...  ..  ..   ...  ..
# 62                250  48.26      8662+          49.16   15  33   4  525+  23
# 63                277  48.25      15525          59.67   27  38  11  1165  24
# 64                266  48.22      3118+          44.77    7   6   1  119+   0
# 65                232  48.21      3217+          60.02    6  13   4  241+  5+
# 66                127  48.00      2110+          25.59    1  10   2   53+   0
#
#    Rookie_year Final_year
# 0         1928       1948
# 1         2022       2023
# 2         2015       2016
# 4         1963       1970
# 5         1930       1954
# ..         ...        ...
# 62        1965       1981
# 63        2002       2014
# 64        1924       1934
# 65        1930       1938
# 66        1928       1934
#
# [64 rows x 17 columns]

# %%
#We have 2 new columns Rookie and Final_year, so we can now get rid of Span
df.drop(['Span'], axis = 1)
# Out:
#                Player  Mat  Inns  Not_outs  Runs Highest_inns_score    Ave  \
# 0    DG Bradman (AUS)   52    80        10  6996                334  99.94
# 1      HC Brook (ENG)   12    20         1  1181                186  62.15
# 2      AC Voges (AUS)   20    31         7  1485               269*  61.87
# 4     RG Pollock (SA)   23    41         4  2256                274  60.97
# 5     GA Headley (WI)   22    40         4  2190               270*  60.83
# ..                ...  ...   ...       ...   ...                ...    ...
# 62   KD Walters (AUS)   74   125        14  5357                250  48.26
# 63  GC Smith (ICC/SA)  117   205        13  9265                277  48.25
# 64  WH Ponsford (AUS)   29    48         4  2122                266  48.22
# 65    SJ McCabe (AUS)   39    62         5  2748                232  48.21
# 66   DR Jardine (ENG)   22    33         6  1296                127  48.00
#
#    Balls_face Batting_strike  100  50   0    4s  6s Rookie_year Final_year
# 0       9800+           58.6   29  13   7  626+   6        1928       1948
# 1        1287          91.76    4   7   1   141  23        2022       2023
# 2        2667          55.68    5   4   2   186   5        2015       2016
# 4       1707+          54.48    7  11   1  246+  11        1963       1970
# 5        416+             56   10   5   2  104+   1        1930       1954
# ..        ...            ...  ...  ..  ..   ...  ..         ...        ...
# 62      8662+          49.16   15  33   4  525+  23        1965       1981
# 63      15525          59.67   27  38  11  1165  24        2002       2014
# 64      3118+          44.77    7   6   1  119+   0        1924       1934
# 65      3217+          60.02    6  13   4  241+  5+        1930       1938
# 66      2110+          25.59    1  10   2   53+   0        1928       1934
#
# [64 rows x 16 columns]

# %%
#Rename the new df
df = df.drop(['Span'], axis = 1)

# %%
df.head()
# Out:
#              Player  Mat  Inns  Not_outs  Runs Highest_inns_score    Ave  \
# 0  DG Bradman (AUS)   52    80        10  6996                334  99.94
# 1    HC Brook (ENG)   12    20         1  1181                186  62.15
# 2    AC Voges (AUS)   20    31         7  1485               269*  61.87
# 4   RG Pollock (SA)   23    41         4  2256                274  60.97
# 5   GA Headley (WI)   22    40         4  2190               270*  60.83
#
#   Balls_face Batting_strike  100  50  0    4s  6s Rookie_year Final_year
# 0      9800+           58.6   29  13  7  626+   6        1928       1948
# 1       1287          91.76    4   7  1   141  23        2022       2023
# 2       2667          55.68    5   4  2   186   5        2015       2016
# 4      1707+          54.48    7  11  1  246+  11        1963       1970
# 5       416+             56   10   5  2  104+   1        1930       1954

# %%
#Now let's split the Player column to have the country on a new column
#First one side
df['Player'].str.split(pat ='(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 4       [RG Pollock , SA)]
# 5       [GA Headley , WI)]
#               ...
# 62     [KD Walters , AUS)]
# 63    [GC Smith , ICC/SA)]
# 64    [WH Ponsford , AUS)]
# 65      [SJ McCabe , AUS)]
# 66     [DR Jardine , ENG)]
# Name: Player, Length: 64, dtype: object

# %%
#Name the new column
df['Country'] = df['Player'].str.split(pat ='(').str[1]

# %%
#Let's see how it looks
df['Country']
# Out:
# 0        AUS)
# 1        ENG)
# 2        AUS)
# 4         SA)
# 5         WI)
#        ...
# 62       AUS)
# 63    ICC/SA)
# 64       AUS)
# 65       AUS)
# 66       ENG)
# Name: Country, Length: 64, dtype: object

# %%
#And now the right side
df['Country'].str.split(pat =')')
# Out:
# 0        [AUS, ]
# 1        [ENG, ]
# 2        [AUS, ]
# 4         [SA, ]
# 5         [WI, ]
#          ...
# 62       [AUS, ]
# 63    [ICC/SA, ]
# 64       [AUS, ]
# 65       [AUS, ]
# 66       [ENG, ]
# Name: Country, Length: 64, dtype: object

# %%
df['Country'] = df['Country'].str.split(pat =')').str[0]

# %%
#Let's see if it worked
df['Country']
# Out:
# 0        AUS
# 1        ENG
# 2        AUS
# 4         SA
# 5         WI
#        ...
# 62       AUS
# 63    ICC/SA
# 64       AUS
# 65       AUS
# 66       ENG
# Name: Country, Length: 64, dtype: object

# %%
#If we run Player, we still have the country
df['Player']
# Out:
# 0      DG Bradman (AUS)
# 1        HC Brook (ENG)
# 2        AC Voges (AUS)
# 4       RG Pollock (SA)
# 5       GA Headley (WI)
#             ...
# 62     KD Walters (AUS)
# 63    GC Smith (ICC/SA)
# 64    WH Ponsford (AUS)
# 65      SJ McCabe (AUS)
# 66     DR Jardine (ENG)
# Name: Player, Length: 64, dtype: object

# %%
#We split again
df['Player'].str.split(pat ='(').str[0]
# Out:
# 0      DG Bradman
# 1        HC Brook
# 2        AC Voges
# 4      RG Pollock
# 5      GA Headley
#           ...
# 62     KD Walters
# 63       GC Smith
# 64    WH Ponsford
# 65      SJ McCabe
# 66     DR Jardine
# Name: Player, Length: 64, dtype: object

# %%
#Rename
df['Player'] = df['Player'].str.split(pat ='(').str[0]

# %%
#Let's check the changes
df.head()
# Out:
#         Player  Mat  Inns  Not_outs  Runs Highest_inns_score    Ave  \
# 0  DG Bradman    52    80        10  6996                334  99.94
# 1    HC Brook    12    20         1  1181                186  62.15
# 2    AC Voges    20    31         7  1485               269*  61.87
# 4  RG Pollock    23    41         4  2256                274  60.97
# 5  GA Headley    22    40         4  2190               270*  60.83
#
#   Balls_face Batting_strike  100  50  0    4s  6s Rookie_year Final_year  \
# 0      9800+           58.6   29  13  7  626+   6        1928       1948
# 1       1287          91.76    4   7  1   141  23        2022       2023
# 2       2667          55.68    5   4  2   186   5        2015       2016
# 4      1707+          54.48    7  11  1  246+  11        1963       1970
# 5       416+             56   10   5  2  104+   1        1930       1954
#
#   Country
# 0     AUS
# 1     ENG
# 2     AUS
# 4      SA
# 5      WI

# %%
##Change data types
#We check which types we have
df.dtypes
# Out:
# Player                 object
# Mat                     int64
# Inns                    int64
# Not_outs                int64
# Runs                    int64
# Highest_inns_score     object
# Ave                   float64
# Balls_face             object
# Batting_strike         object
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Rookie_year            object
# Final_year             object
# Country                object
# dtype: object

# %%
#It recognises Highest_inns_score as an object because of the * symbol, let's change it
df['Highest_inns_score'].str.split(pat ='*').str[0]
# Out:
# 0     334
# 1     186
# 2     269
# 4     274
# 5     270
#      ...
# 62    250
# 63    277
# 64    266
# 65    232
# 66    127
# Name: Highest_inns_score, Length: 64, dtype: object

# %%
#Assign it
df['Highest_inns_score'] = df['Highest_inns_score'].str.split(pat ='*').str[0]

# %%
#Let's check it worked
df['Highest_inns_score']
# Out:
# 0     334
# 1     186
# 2     269
# 4     274
# 5     270
#      ...
# 62    250
# 63    277
# 64    266
# 65    232
# 66    127
# Name: Highest_inns_score, Length: 64, dtype: object

# %%
#Now let's change it to integer
df['Highest_inns_score'].astype('int')
# Out:
# 0     334
# 1     186
# 2     269
# 4     274
# 5     270
#      ...
# 62    250
# 63    277
# 64    266
# 65    232
# 66    127
# Name: Highest_inns_score, Length: 64, dtype: int64

# %%
#Now let's change Rookie and End year
df['Rookie_year'].astype('int')
# Out:
# 0     1928
# 1     2022
# 2     2015
# 4     1963
# 5     1930
#       ...
# 62    1965
# 63    2002
# 64    1924
# 65    1930
# 66    1928
# Name: Rookie_year, Length: 64, dtype: int64

# %%
#End year
df['Final_year'].astype('int')
# Out:
# 0     1948
# 1     2023
# 2     2016
# 4     1970
# 5     1954
#       ...
# 62    1981
# 63    2014
# 64    1934
# 65    1938
# 66    1934
# Name: Final_year, Length: 64, dtype: int64

# %%
#We need Batting strike as a float
df['Batting_strike'] = df['Batting_strike'].astype('float')
#It's not working, we'll come back later
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-6c39afb5dc36> in <module>
#       1 #We need Batting strike as a float
# ----> 2 df['Batting_strike'] = df['Batting_strike'].astype('float')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1095     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#    1096         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1097         return arr.astype(dtype, copy=True)
#    1098
#    1099     return arr.view(dtype)
#
# ValueError: could not convert string to float: '-'

# %%
df.dtypes
# Out:
# Player                 object
# Mat                     int64
# Inns                    int64
# Not_outs                int64
# Runs                    int64
# Highest_inns_score     object
# Ave                   float64
# Balls_face             object
# Batting_strike         object
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Rookie_year            object
# Final_year             object
# Country                object
# dtype: object

# %%
#Let's carry on with matches
df['Highest_inns_score'].astype('int')
df.dtypes
# Out:
# Player                 object
# Mat                     int64
# Inns                    int64
# Not_outs                int64
# Runs                    int64
# Highest_inns_score     object
# Ave                   float64
# Balls_face             object
# Batting_strike         object
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Rookie_year            object
# Final_year             object
# Country                object
# dtype: object

# %%
df = df.astype({'Rookie_year':'int', 'Final_year':'int'})

# %%
df.dtypes
# Out:
# Player                 object
# Mat                     int64
# Inns                    int64
# Not_outs                int64
# Runs                    int64
# Highest_inns_score     object
# Ave                   float64
# Balls_face             object
# Batting_strike         object
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Rookie_year             int64
# Final_year              int64
# Country                object
# dtype: object

# %%
#For Balls_face, we have +
df['Balls_face'] = df['Balls_face'].str.split(pat ='+').str[0]

# %%
#Convert
df['Balls_face'] = df['Balls_face'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-8b9d2df70488> in <module>
#       1 #Convert
# ----> 2 df['Balls_face'] = df['Balls_face'].astype('int')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1072         # work around NumPy brokenness, #1987
#    1073         if np.issubdtype(dtype.type, np.integer):
# -> 1074             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    1075
#    1076         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: ' '

# %%
#We cant convert it to Int, let's see why
df['Balls_face']
# Out:
# 0      9800
# 1      1287
# 2      2667
# 4      1707
# 5       416
#       ...
# 62     8662
# 63    15525
# 64     3118
# 65     3217
# 66     2110
# Name: Balls_face, Length: 64, dtype: object

# %%
#Let's run this 
df.isnull().any()
#Apparently there's a null value, that's why we can't convert it to Int
# Out:
# Player                False
# Mat                   False
# Inns                  False
# Not_outs              False
# Runs                  False
# Highest_inns_score    False
# Ave                   False
# Balls_face             True
# Batting_strike        False
# 100                   False
# 50                    False
# 0                     False
# 4s                    False
# 6s                    False
# Rookie_year           False
# Final_year            False
# Country               False
# dtype: bool

# %%
df['Balls_face'] = df['Balls_face'].str.split(pat = '+').str[0]

# %%
df['Balls_face']
# Out:
# 0      9800
# 1      1287
# 2      2667
# 4      1707
# 5       416
#       ...
# 62     8662
# 63    15525
# 64     3118
# 65     3217
# 66     2110
# Name: Balls_face, Length: 64, dtype: object

# %%
df['Balls_face'] = df['Balls_face'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-103-9687f4840943> in <module>
# ----> 1 df['Balls_face'] = df['Balls_face'].astype('int')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1072         # work around NumPy brokenness, #1987
#    1073         if np.issubdtype(dtype.type, np.integer):
# -> 1074             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    1075
#    1076         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: ' '

# %%
df[df['Balls_face'].isna()==1]
# Out:
#          Player  Mat  Inns  Not_outs  Runs Highest_inns_score    Ave  \
# 17  CL Walcott    44    74         7  3798                220  56.68
#
#    Balls_face Batting_strike  100  50  0    4s  6s  Rookie_year  Final_year  \
# 17        NaN              0   15  14  1  107+  11         1948        1960
#
#    Country
# 17      WI

# %%
df['Balls_face'] = df['Balls_face'].fillna(0)

# %%
df['Balls_face']
# Out:
# 0      9800
# 1      1287
# 2      2667
# 4      1707
# 5       416
#       ...
# 62     8662
# 63    15525
# 64     3118
# 65     3217
# 66     2110
# Name: Balls_face, Length: 64, dtype: object

# %%
df['Balls_face'] = df['Balls_face'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-9687f4840943> in <module>
# ----> 1 df['Balls_face'] = df['Balls_face'].astype('int')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1072         # work around NumPy brokenness, #1987
#    1073         if np.issubdtype(dtype.type, np.integer):
# -> 1074             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    1075
#    1076         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: ' '

# %%
df[df['Balls_face'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Mat, Inns, Not_outs, Runs, Highest_inns_score, Ave, Balls_face, Batting_strike, 100, 50, 0, 4s, 6s, Rookie_year, Final_year, Country]
# Index: []

# %%
#It still is not working even though there are no null values
#Let's display the whole document to find potential issues
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#                 Player  Mat  Inns  Not_outs   Runs Highest_inns_score    Ave  \
# 0          DG Bradman    52    80        10   6996                334  99.94
# 1            HC Brook    12    20         1   1181                186  62.15
# 2            AC Voges    20    31         7   1485                269  61.87
# 4          RG Pollock    23    41         4   2256                274  60.97
# 5          GA Headley    22    40         4   2190                270  60.83
# 6         H Sutcliffe    54    84         9   4555                194  60.73
# 7           E Paynter    20    31         5   1540                243  59.23
# 8       KF Barrington    82   131        15   6806                256  58.67
# 9           ED Weekes    48    81         5   4455                207  58.61
# 10          SPD Smith   102   181        22   9320                239  58.61
# 11         WR Hammond    85   140        16   7249                336  58.45
# 12          GS Sobers    93   160        21   8032                365  57.78
# 13      KC Sangakkara   134   233        17  12400                319  57.40
# 14        DJ Mitchell    18    27         4   1316                190  57.21
# 15           JB Hobbs    61   102         7   5410                211  56.94
# 17         CL Walcott    44    74         7   3798                220  56.68
# 18           L Hutton    79   138        15   6971                364  56.67
# 19          JH Kallis   166   280        40  13289                224  55.37
# 20       GE Tyldesley    14    20         2    990                122  55.00
# 21      KS Williamson    94   164        16   8124                251  54.89
# 22           CA Davis    15    29         5   1301                183  54.20
# 23          VG Kambli    17    21         1   1084                227  54.20
# 25        GS Chappell    87   151        19   7110                247  53.86
# 26          AD Nourse    34    62         7   2960                231  53.81
# 44        1994      AUS
# 45        2023      ENG
# 46        1991       WI
# 47        2023       NZ
# 48        1957      ENG
# 49        2014       SL
# 50        2007  ICC/PAK
# 51        1963       WI
# 52        1928      ENG
# 53        2013  ICC/IND
# 54        2023      IND
# 55        2021      PAK
# 56        2015      AUS
# 57        1966       SA
# 58        1949       SA
# 59        1905      ENG
# 60        2013       SL
# 61        1963      AUS
# 62        1981      AUS
# 63        2014   ICC/SA
# 64        1934      AUS
# 65        1938      AUS
# 66        1934      ENG

# %%
df['Balls_face']
# Out:
# 0      9800
# 1      1287
# 2      2667
# 4      1707
# 5       416
# 6      6558
# 7      1288
# 8      4957
# 9
# 10    17292
# 11     7491
# 12     4063
# 13    22882
# 14     2395
# 15     5363
# 17        0
# 18     2844
# 19    28903
# 20      178
# 21    15785
# 22      665
# 23     1823
# 25    13079
# 26      108
# 27    29437
# 28     7146
# 29    19753
# 30    15164
# 31    31258
# 32    14372
# 33    19375
# 34    22782
# 35     2035
# 36    10636
# 37    12436
# 38    27395
# 39    14184
# 40    22461
# 41     2764
# 42    14349
# 43    16077
# 44    27002
# 45    20113
# 46     9613
# 47     2719
# 48     2731
# 49    22959
# 50    16345
# 51      488
# 52      619
# 53    10441
# 54    15708
# 55     2445
# 56    15456
# 57      885
# 58      158
# 59
# 60    11641
# 61     1799
# 62     8662
# 63    15525
# 64     3118
# 65     3217
# 66     2110
# Name: Balls_face, dtype: object

# %%
# Assuming your data is in a DataFrame called df
def clean_and_convert_to_int(value):
    try:
        return int(value)
    except (ValueError, TypeError):
        return 0

df['Balls_face'] = df['Balls_face'].apply(clean_and_convert_to_int)

# Now the "Balls_face" column should contain integers or 0 for non-numeric values

# %%
df['Balls_face']
# Out:
# 0      9800
# 1      1287
# 2      2667
# 4      1707
# 5       416
# 6      6558
# 7      1288
# 8      4957
# 9         0
# 10    17292
# 11     7491
# 12     4063
# 13    22882
# 14     2395
# 15     5363
# 17        0
# 18     2844
# 19    28903
# 20      178
# 21    15785
# 22      665
# 23     1823
# 25    13079
# 26      108
# 27    29437
# 28     7146
# 29    19753
# 30    15164
# 31    31258
# 32    14372
# 33    19375
# 34    22782
# 35     2035
# 36    10636
# 37    12436
# 38    27395
# 39    14184
# 40    22461
# 41     2764
# 42    14349
# 43    16077
# 44    27002
# 45    20113
# 46     9613
# 47     2719
# 48     2731
# 49    22959
# 50    16345
# 51      488
# 52      619
# 53    10441
# 54    15708
# 55     2445
# 56    15456
# 57      885
# 58      158
# 59        0
# 60    11641
# 61     1799
# 62     8662
# 63    15525
# 64     3118
# 65     3217
# 66     2110
# Name: Balls_face, dtype: int64

# %%
df.dtypes
# Out:
# Player                 object
# Mat                     int64
# Inns                    int64
# Not_outs                int64
# Runs                    int64
# Highest_inns_score     object
# Ave                   float64
# Balls_face              int64
# Batting_strike         object
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Rookie_year             int64
# Final_year              int64
# Country                object
# dtype: object

# %%
#Now Batting strike
df['Batting_strike'] = df['Batting_strike'].astype('float64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-a0670c7cccae> in <module>
#       1 #Now Batting strike
# ----> 2 df['Batting_strike'] = df['Batting_strike'].astype('float64')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1095     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#    1096         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1097         return arr.astype(dtype, copy=True)
#    1098
#    1099     return arr.view(dtype)
#
# ValueError: could not convert string to float: '-'

# %%
df['Batting_strike'] = df['Batting_strike'].str.split(pat = '-').str[0]

# %%
df['Batting_strike'] = df['Batting_strike'].astype('float64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-b3fe75ac5861> in <module>
# ----> 1 df['Batting_strike'] = df['Batting_strike'].astype('float64')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1095     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#    1096         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1097         return arr.astype(dtype, copy=True)
#    1098
#    1099     return arr.view(dtype)
#
# ValueError: could not convert string to float: ''

# %%
df['Batting_strike']
# Out:
# 0      58.6
# 1     91.76
# 2     55.68
# 4     54.48
# 5        56
# 6     34.59
# 7     45.88
# 8     42.42
# 9         0
# 10    53.89
# 11    38.07
# 12    53.58
# 13    54.19
# 14    54.94
# 15    46.22
# 17        0
# 18    39.34
# 19    45.97
# 20    29.21
# 21    51.46
# 22    35.48
# 23    59.46
# 25    51.53
# 26    63.88
# 27    54.04
# 28    53.02
# 29    60.51
# 30    45.99
# 31    42.51
# 32    52.39
# 33    52.12
# 34    58.72
# 35    44.86
# 36    45.07
# 37    50.13
# 38    43.31
# 39    43.35
# 40    48.64
# 41    44.13
# 42     60.1
# 43    54.51
# 44    41.09
# 45    56.75
# 46    69.77
# 47    51.59
# 48    38.81
# 49    51.45
# 50    54.02
# 51    40.16
# 52    30.04
# 53    82.23
# 54    55.23
# 55    48.26
# 56    55.92
# 57    37.74
# 58    29.11
# 59
# 60    46.92
# 61    43.74
# 62    49.16
# 63    59.67
# 64    44.77
# 65    60.02
# 66    25.59
# Name: Batting_strike, dtype: object

# %%
df[df['Batting_strike'].isna()==1]
# Out:
#          Player  Mat  Inns  Not_outs  Runs Highest_inns_score    Ave  \
# 9    ED Weekes    48    81         5  4455                207  58.61
# 17  CL Walcott    44    74         7  3798                220  56.68
#
#     Balls_face Batting_strike  100  50  0    4s  6s  Rookie_year  Final_year  \
# 9            0            NaN   15  19  6  258+   2         1948        1958
# 17           0            NaN   15  14  1  107+  11         1948        1960
#
#    Country
# 9       WI
# 17      WI

# %%
df['Batting_strike'] = df['Batting_strike'].fillna(0)

# %%
#Empty spaces
def clean_and_convert_to_float64(value):
    try:
        return int(value)
    except (ValueError, TypeError):
        return 0

df['Batting_strike'] = df['Batting_strike'].apply(clean_and_convert_to_float64)

# %%
df.dtypes
# Out:
# Player                 object
# Mat                     int64
# Inns                    int64
# Not_outs                int64
# Runs                    int64
# Highest_inns_score     object
# Ave                   float64
# Balls_face              int64
# Batting_strike          int64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Rookie_year             int64
# Final_year              int64
# Country                object
# dtype: object

# %%
df['Batting_strike'] = df['Batting_strike'].astype('float64')

# %%
df.dtypes
# Out:
# Player                 object
# Mat                     int64
# Inns                    int64
# Not_outs                int64
# Runs                    int64
# Highest_inns_score     object
# Ave                   float64
# Balls_face              int64
# Batting_strike        float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Rookie_year             int64
# Final_year              int64
# Country                object
# dtype: object

# %%
##Build out a new column of Career lenght
df['Career_lenght'] = df['Final_year'] - df['Rookie_year']

# %%
df
# Out:
#                 Player  Mat  Inns  Not_outs   Runs Highest_inns_score    Ave  \
# 0          DG Bradman    52    80        10   6996                334  99.94
# 61        1799             0.0   21  24   7   427+    1         1948
# 62        8662             0.0   15  33   4   525+   23         1965
# 63       15525             0.0   27  38  11   1165   24         2002
# 64        3118             0.0    7   6   1   119+    0         1924
# 65        3217             0.0    6  13   4   241+   5+         1930
# 66        2110             0.0    1  10   2    53+    0         1928
#
#     Final_year  Country  Career_lenght
# 0         1948      AUS             20
# 1         2023      ENG              1
# 2         2016      AUS              1
# 4         1970       SA              7
# 5         1954       WI             24
# 6         1935      ENG             11
# 7         1939      ENG              8
# 8         1968      ENG             13
# 9         1958       WI             10
# 10        2023      AUS             13
# 11        1947      ENG             20
# 12        1974       WI             20
# 13        2015       SL             15
# 14        2023       NZ              4
# 15        1930      ENG             22
# 17        1960       WI             12
# 18        1955      ENG             18
# 19        2013   ICC/SA             18
# 20        1929      ENG              8
# 21        2023       NZ             13
# 22        1973       WI              5
# 23        1995      IND              2
# 25        1984      AUS             14
# 26        1951       SA             16
# 27        2013      IND             24
# 28        2023      AUS              5
# 29        2006   ICC/WI             16
# 30        1993      PAK             17
# 31        2012  ICC/IND             16
# 32        2010      PAK             12
# 33        2017      PAK             17
# 34        2012      AUS             17
# 35        1929      AUS              9
# 36        2002      ZIM             10
# 37        2013      AUS              8
# 38        2015       WI             21
# 39        1987      IND             16
# 40        2004      AUS             19
# 41        2023      PAK              2
# 42        2009      AUS             15
# 43        2018       SA             14
# 44        1994      AUS             16
# 45        2023      ENG             11
# 46        1991       WI             17
# 47        2023       NZ              2
# 48        1957      ENG             20
# 49        2014       SL             17
# 50        2007  ICC/PAK             15
# 51        1963       WI             15
# 52        1928      ENG             17
# 53        2013  ICC/IND             12
# 54        2023      IND             12
# 55        2021      PAK              2
# 56        2015      AUS             11
# 57        1966       SA              5
# 58        1949       SA             20
# 59        1905      ENG             12
# 60        2013       SL             12
# 61        1963      AUS             15
# 62        1981      AUS             16
# 63        2014   ICC/SA             12
# 64        1934      AUS             10
# 65        1938      AUS              8
# 66        1934      ENG              6

# %%
#So now we can answer new questions
#What is the average career lenght?
df['Career_lenght'].mean()
# Out:
# 12.75

# %%
#Batting strike rate for players who played the last 10 years
df[df['Career_lenght'] > 10]['Batting_strike'].mean()
# Out:
# 1.2727272727272727

# %%
#Number of cricketers who played before 1960
df[df['Rookie_year'] < 1960]
# Out:
#              Player  Mat  Inns  Not_outs  Runs Highest_inns_score    Ave  \
# 0       DG Bradman    52    80        10  6996                334  99.94
# 5       GA Headley    22    40         4  2190                270  60.83
# 6      H Sutcliffe    54    84         9  4555                194  60.73
# 7        E Paynter    20    31         5  1540                243  59.23
# 8    KF Barrington    82   131        15  6806                256  58.67
# 9        ED Weekes    48    81         5  4455                207  58.61
# 11      WR Hammond    85   140        16  7249                336  58.45
# 12       GS Sobers    93   160        21  8032                365  57.78
# 15        JB Hobbs    61   102         7  5410                211  56.94
# 17      CL Walcott    44    74         7  3798                220  56.68
# 18        L Hutton    79   138        15  6971                364  56.67
# 20    GE Tyldesley    14    20         2   990                122  55.00
# 26       AD Nourse    34    62         7  2960                231  53.81
# 35         J Ryder    20    32         5  1394                201  51.62
# 48     DCS Compton    78   131        15  5807                278  50.06
# 51     FMM Worrell    51    87         9  3860                261  49.48
# 52         CP Mead    17    26         2  1185                182  49.37
# 58      B Mitchell    42    80         9  3471                189  48.88
# 59  Hon.FS Jackson    20    33         4  1415                144  48.79
# 61       RN Harvey    79   137        10  6149                205  48.41
# 64     WH Ponsford    29    48         4  2122                266  48.22
# 65       SJ McCabe    39    62         5  2748                232  48.21
# 66      DR Jardine    22    33         6  1296                127  48.00
#
#     Balls_face  Batting_strike  100  50   0    4s   6s  Rookie_year  \
# 0         9800             0.0   29  13   7  626+    6         1928
# 5          416            56.0   10   5   2  104+    1         1930
# 6         6558             0.0   16  23   2  202+    6         1924
# 7         1288             0.0    4   7   3  125+    4         1931
# 8         4957             0.0   20  35   5  591+   27         1955
# 9            0             0.0   15  19   6  258+    2         1948
# 11        7491             0.0   22  24   4  419+   27         1927
# 12        4063             0.0   26  30  12  593+  32+         1954
# 15        5363             0.0   15  28   4  276+    8         1908
# 17           0             0.0   15  14   1  107+   11         1948
# 18        2844             0.0   19  33   5  358+    7         1937
# 20         178             0.0    3   6   2   37+    2         1921
# 26         108             0.0    9  14   3  115+    6         1935
# 35        2035             0.0    3   9   1  102+    3         1920
# 48        2731             0.0   17  28  10  342+    3         1937
# 51         488             0.0    9  22  11  240+   11         1948
# 52         619             0.0    4   3   3   38+    0         1911
# 58         158             0.0    8  21   3   41+    1         1929
# 59           0             0.0    5   6   3   51+    0         1893
# 61        1799             0.0   21  24   7  427+    1         1948
# 64        3118             0.0    7   6   1  119+    0         1924
# 65        3217             0.0    6  13   4  241+   5+         1930
# 66        2110             0.0    1  10   2   53+    0         1928
#
#     Final_year Country  Career_lenght
# 0         1948     AUS             20
# 5         1954      WI             24
# 6         1935     ENG             11
# 7         1939     ENG              8
# 8         1968     ENG             13
# 9         1958      WI             10
# 11        1947     ENG             20
# 12        1974      WI             20
# 15        1930     ENG             22
# 17        1960      WI             12
# 18        1955     ENG             18
# 20        1929     ENG              8
# 26        1951      SA             16
# 35        1929     AUS              9
# 48        1957     ENG             20
# 51        1963      WI             15
# 52        1928     ENG             17
# 58        1949      SA             20
# 59        1905     ENG             12
# 61        1963     AUS             15
# 64        1934     AUS             10
# 65        1938     AUS              8
# 66        1934     ENG              6

# %%
#Highest Inns score by country
df.groupby('Country')['Highest_inns_score'].max()
# Out:
# Country
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        254
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: Highest_inns_score, dtype: object

# %%
#The same but with a different format and ascending
df.groupby('Country')['Highest_inns_score'].max().to_frame('Highest_inns_Country').reset_index().sort_values('Highest_inns_Country',ascending = False)
# Out:
#     Country Highest_inns_Country
# 5    ICC/WI                  400
# 0       AUS                  380
# 10       SL                  374
# 11       WI                  365
# 1       ENG                  364
# 3   ICC/PAK                  329
# 2   ICC/IND                  319
# 8       PAK                  313
# 9        SA                  278
# 4    ICC/SA                  277
# 6       IND                  254
# 7        NZ                  251
# 12      ZIM                  232
